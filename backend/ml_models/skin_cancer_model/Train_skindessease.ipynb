# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# Load Datasets
training_set = tf.keras.utils.image_dataset_from_directory(
    'train',
    labels="inferred",
    label_mode="categorical",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True
)

validation_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True
)

# Extract class names
class_names = training_set.class_names

# Define Model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu', input_shape=(128, 128, 3)),
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(2, 2),

    tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(64, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(2, 2),

    tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(128, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(2, 2),

    tf.keras.layers.Conv2D(256, 3, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(256, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(2, 2),

    tf.keras.layers.Conv2D(512, 3, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(512, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(2, 2),

    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1500, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    
    # Output layer with correct number of classes
    tf.keras.layers.Dense(len(class_names), activation='softmax')
])

# Compile Model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Model Summary
model.summary()

# Train Model
training_history = model.fit(
    training_set,
    validation_data=validation_set,
    epochs=20
)

# Evaluate Model
train_loss, train_acc = model.evaluate(training_set)
print("Training Loss:", train_loss, "Training Accuracy:", train_acc)

val_loss, val_acc = model.evaluate(validation_set)
print("Validation Loss:", val_loss, "Validation Accuracy:", val_acc)

# Save Model
model.save("trained_model.keras")

# Save Training History
import json
with open("training_hist.json", "w") as f:
    json.dump(training_history.history, f)

# Accuracy Plot
epochs = range(1, len(training_history.history['accuracy']) + 1)  # ✅ Matches actual training epochs

plt.plot(epochs, training_history.history['accuracy'], color='red', label='Training Accuracy')
plt.plot(epochs, training_history.history['val_accuracy'], color='blue', label='Validation Accuracy')
plt.xlabel("No. of Epochs")
plt.ylabel("Accuracy")
plt.title("Model Accuracy over Epochs")
plt.legend()
plt.show()

# Load Test Set
test_set = tf.keras.utils.image_dataset_from_directory(
    'valid',  # Assuming 'valid' is the test set
    labels="inferred",
    label_mode="categorical",
    batch_size=32,
    image_size=(128, 128),
    shuffle=False
)

# Predictions
y_pred = model.predict(test_set)
predicted_categories = tf.argmax(y_pred, axis=1)

# Convert Tensor to NumPy
predicted_categories = predicted_categories.numpy()
true_categories = tf.concat([y for x, y in test_set], axis=0)
Y_true = tf.argmax(true_categories, axis=1).numpy()

# Classification Report
print(classification_report(Y_true, predicted_categories, target_names=class_names))

# Confusion Matrix
cm = confusion_matrix(Y_true, predicted_categories)




plt.plot(epochs, training_history.history['accuracy'], color='red', label='Training Accuracy')
plt.plot(epochs, training_history.history['val_accuracy'], color='blue', label='Validation Accuracy')
plt.xlabel("Number of Epochs")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.show()
# Plot Confusion Matrix
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Found 2240 files belonging to 9 classes.
# Found 2239 files belonging to 9 classes.
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape          ┃      Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │ conv2d_20 (Conv2D)            │ (None, 128, 128, 32)  │          896 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ conv2d_21 (Conv2D)            │ (None, 126, 126, 32)  │        9,248 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ max_pooling2d_10              │ (None, 63, 63, 32)    │            0 │
# │ (MaxPooling2D)                │                       │              │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ conv2d_22 (Conv2D)            │ (None, 63, 63, 64)    │       18,496 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ conv2d_23 (Conv2D)            │ (None, 61, 61, 64)    │       36,928 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ max_pooling2d_11              │ (None, 30, 30, 64)    │            0 │
# │ (MaxPooling2D)                │                       │              │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ conv2d_24 (Conv2D)            │ (None, 30, 30, 128)   │       73,856 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ conv2d_25 (Conv2D)            │ (None, 28, 28, 128)   │      147,584 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ max_pooling2d_12              │ (None, 14, 14, 128)   │            0 │
# │ (MaxPooling2D)                │                       │              │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ conv2d_26 (Conv2D)            │ (None, 14, 14, 256)   │      295,168 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ conv2d_27 (Conv2D)            │ (None, 12, 12, 256)   │      590,080 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ max_pooling2d_13              │ (None, 6, 6, 256)     │            0 │
# │ (MaxPooling2D)                │                       │              │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ conv2d_28 (Conv2D)            │ (None, 6, 6, 512)     │    1,180,160 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ conv2d_29 (Conv2D)            │ (None, 4, 4, 512)     │    2,359,808 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ max_pooling2d_14              │ (None, 2, 2, 512)     │            0 │
# │ (MaxPooling2D)                │                       │              │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ dropout_4 (Dropout)           │ (None, 2, 2, 512)     │            0 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ flatten_2 (Flatten)           │ (None, 2048)          │            0 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ dense_4 (Dense)               │ (None, 1500)          │    3,073,500 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ dropout_5 (Dropout)           │ (None, 1500)          │            0 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ dense_5 (Dense)               │ (None, 9)             │       13,509 │
# └───────────────────────────────┴───────────────────────┴──────────────┘
#  Total params: 7,799,233 (29.75 MB)
#  Trainable params: 7,799,233 (29.75 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 59s 808ms/step - accuracy: 0.1992 - loss: 2.3033 - val_accuracy: 0.3265 - val_loss: 1.8483
# Epoch 2/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 56s 808ms/step - accuracy: 0.3499 - loss: 1.7217 - val_accuracy: 0.4591 - val_loss: 1.4867
# Epoch 3/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 56s 806ms/step - accuracy: 0.4372 - loss: 1.5528 - val_accuracy: 0.4958 - val_loss: 1.4334
# Epoch 4/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 219s 3s/step - accuracy: 0.5034 - loss: 1.4490 - val_accuracy: 0.5159 - val_loss: 1.3583
# Epoch 5/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 56s 800ms/step - accuracy: 0.5068 - loss: 1.4086 - val_accuracy: 0.4506 - val_loss: 1.5483
# Epoch 6/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 56s 796ms/step - accuracy: 0.4995 - loss: 1.4318 - val_accuracy: 0.5610 - val_loss: 1.2523
# Epoch 7/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 112s 2s/step - accuracy: 0.5297 - loss: 1.3251 - val_accuracy: 0.5552 - val_loss: 1.2704
# Epoch 8/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 56s 805ms/step - accuracy: 0.5361 - loss: 1.2958 - val_accuracy: 0.5797 - val_loss: 1.1882
# Epoch 9/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 56s 793ms/step - accuracy: 0.5619 - loss: 1.2455 - val_accuracy: 0.5909 - val_loss: 1.1662
# Epoch 10/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 55s 789ms/step - accuracy: 0.5767 - loss: 1.2005 - val_accuracy: 0.6128 - val_loss: 1.1170
# Epoch 11/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 9698s 141s/step - accuracy: 0.5901 - loss: 1.1389 - val_accuracy: 0.5922 - val_loss: 1.1348
# Epoch 12/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.5939 - loss: 1.1262 - val_accuracy: 0.6445 - val_loss: 0.9985
# Epoch 13/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.6178 - loss: 1.0975 - val_accuracy: 0.6655 - val_loss: 0.9463
# Epoch 14/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.6264 - loss: 1.0447 - val_accuracy: 0.6731 - val_loss: 0.9250
# Epoch 15/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1828s 26s/step - accuracy: 0.6433 - loss: 1.0096 - val_accuracy: 0.6677 - val_loss: 0.9390
# Epoch 16/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 63s 906ms/step - accuracy: 0.6562 - loss: 0.9583 - val_accuracy: 0.7079 - val_loss: 0.8239
# Epoch 17/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 55s 788ms/step - accuracy: 0.6812 - loss: 0.9052 - val_accuracy: 0.6950 - val_loss: 0.8791
# Epoch 18/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 54s 778ms/step - accuracy: 0.6984 - loss: 0.8531 - val_accuracy: 0.7343 - val_loss: 0.7546
# Epoch 19/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 55s 785ms/step - accuracy: 0.7329 - loss: 0.7654 - val_accuracy: 0.7628 - val_loss: 0.6487
# Epoch 20/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 55s 789ms/step - accuracy: 0.7300 - loss: 0.7279 - val_accuracy: 0.8017 - val_loss: 0.5970
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 14s 202ms/step - accuracy: 0.7815 - loss: 0.6283
# Training Loss: 0.5969439744949341 Training Accuracy: 0.8017857074737549
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 13s 191ms/step - accuracy: 0.8122 - loss: 0.5850
# Validation Loss: 0.5970422625541687 Validation Accuracy: 0.8016971945762634
# Found 2239 files belonging to 9 classes.
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 13s 185ms/step
#                             precision    recall  f1-score   support
#
#          actinic keratosis       0.56      0.53      0.54       114
#       basal cell carcinoma       0.90      0.79      0.84       376
#             dermatofibroma       0.83      0.73      0.78        95
#                   melanoma       0.80      0.90      0.85       438
#                      nevus       0.76      0.85      0.80       357
# pigmented benign keratosis       0.96      0.77      0.86       462
#       seborrheic keratosis       0.52      0.16      0.24        77
#    squamous cell carcinoma       0.56      0.90      0.69       181
#            vascular lesion       0.99      1.00      0.99       139
#
#                   accuracy                           0.80      2239
#                  macro avg       0.76      0.74      0.73      2239
#               weighted avg       0.82      0.80      0.80      2239
